# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt

# %%
g = 9.81
m = 1
w = g*m
Thrust_max = 9 # Newton

total_force_min = w
total_force_max = w - Thrust_max*4  

print(total_force_min, total_force_max)
# Out:
# 9.81 -26.189999999999998

# %%
u = 9.81
req_thrust = w - u
print(req_thrust)
# Out:
# 0.0
