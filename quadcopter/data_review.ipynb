# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
np.set_printoptions(suppress=True, precision=2)

# %%
data = pd.read_csv('data/imu_x.csv')
angvel = data['angVel_x'].values

print(angvel)
# Out:
# [ 0.    0.    0.   ... -0.14 -0.15 -0.15]

# %%
ts = data['ts'].values
ts = ts - ts[0]

plt.figure()
plt.plot(ts, angvel)
